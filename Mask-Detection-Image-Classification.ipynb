# %% [markdown]
# # Image Classification Imports

# %%
from pathlib import Path
import tensorflow as tf
import numpy as np
import imghdr
import os
import pathlib
import time
import matplotlib.pyplot as plt

AUTOTUNE = tf.data.AUTOTUNE

# %% [markdown]
# # Function Definitions

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
def changeFileNames(folder = ""):
    count = 1
    for i in os.listdir(folder):
        source = folder + i
        destination = folder + "Images_" + str(count) + ".jpeg"
        os.rename(source, destination)
        count += 1
    print("All files renamed")

# %%
def checkUnableFiles(pathName = ""):
    data_dir = pathlib.Path(pathName)
    image_extensions = [".png", ".jpg"]  # add there all your images file extensions
    img_type_accepted_by_tf = ["bmp", "gif", "jpeg", "png"]
    for filepath in Path(data_dir).rglob("*"):
        if filepath.suffix.lower() in image_extensions:
            img_type = imghdr.what(filepath)
            if img_type is None:
                print(f"{filepath} is not an image")
            elif img_type not in img_type_accepted_by_tf:
                print(f"{filepath} is a {img_type}, not accepted by TensorFlow")

# %%
def decode_img(img):
    # Convert the compressed string to a 3D uint8 tensor
    img = tf.io.decode_jpeg(img, channels=3)
    # Resize the image to the desired size
    return tf.image.resize(img, [img_height, img_width])

# %%
def process_path(file_path):
    label = gel_label(file_path)
    # Load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    img = decode_img(img)
    return img, label

# %%
def configure_for_performance(ds):
    ds = ds.cache()
    ds = ds.shuffle(buffer_size = 1000)
    ds = ds.batch(batch_size)
    ds = ds.prefetch(buffer_size = AUTOTUNE)
    return ds

# %% [markdown]
# # Prepare Dataset

# %%
checkUnableFiles("Data")

# %%
data_dir = pathlib.Path("Data/")
jpg_files = list(data_dir.glob("**/*.jpg"))
png_files = list(data_dir.glob("**/*.png"))
jpeg_files = list(data_dir.glob("**/*.jpeg"))
all_files = jpg_files + png_files + jpeg_files

image_count = len(all_files)

# %%
image_count
# Out:
# 8118

# %%
list_ds = tf.data.Dataset.list_files(str(data_dir/'*/*'), shuffle=False)
list_ds = list_ds.shuffle(image_count, reshuffle_each_iteration=False)

# %%
for f in list_ds.take(5):
    print(f.numpy())
# Out:
# b'Data\\With_mask\\Images_2462.jpeg'
# b'Data\\Without_mask\\Images_3267.jpeg'
# b'Data\\Without_mask\\Images_631.jpeg'
# b'Data\\Without_mask\\Images_1678.jpeg'
# b'Data\\With_mask\\Images_977.jpeg'

# %%
class_names = np.array(sorted([item.name for item in data_dir.glob('*') if item.name != "LICENSE.txt"]))
class_names = ['With_mask', 'Without_mask']
print(class_names)
# Out:
# ['With_mask', 'Without_mask']

# %%
def gel_label(file_path):
    # Convert the path to a list of path components
    parts = tf.strings.split(file_path, os.path.sep)
    # The second to last is the class-directory
    one_hot = parts[-2] == class_names
    # Integer encode the label
    return tf.argmax(one_hot)

# %%
val_size = int(image_count *0.2)
train_ds = list_ds.skip(val_size)
val_ds = list_ds.take(val_size)

# %%
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
# Out:
# 6495
# 1623

# %%
# Set 'num_parallel_calls' so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(process_path, num_parallel_calls = AUTOTUNE)
val_ds = val_ds.map(process_path, num_parallel_calls= AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image Shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image Shape:  (180, 180, 3)
# Label:  0

# %%
train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)

# %%
image_batch, label_batch = next(iter(train_ds))

plt.figure(figsize=(15,15))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image_batch[i].numpy().astype("uint8"))
    label = label_batch[i]
    plt.title(class_names[label])
    plt.axis("off")

# %%
num_classes = 2

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
t1 = time.time()
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=20
)
t2 = time.time()
print(t2-t1)
# Out:
# Epoch 1/20
# 203/203 [==============================] - 14s 32ms/step - loss: 0.2841 - accuracy: 0.8851 - val_loss: 0.2248 - val_accuracy: 0.9150
# Epoch 2/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.1782 - accuracy: 0.9350 - val_loss: 0.1937 - val_accuracy: 0.9267
# Epoch 3/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.1240 - accuracy: 0.9517 - val_loss: 0.1404 - val_accuracy: 0.9445
# Epoch 4/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0934 - accuracy: 0.9634 - val_loss: 0.1479 - val_accuracy: 0.9513
# Epoch 5/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0665 - accuracy: 0.9738 - val_loss: 0.1562 - val_accuracy: 0.9421
# Epoch 6/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0528 - accuracy: 0.9794 - val_loss: 0.1546 - val_accuracy: 0.9476
# Epoch 7/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0283 - accuracy: 0.9909 - val_loss: 0.1980 - val_accuracy: 0.9526
# Epoch 8/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0293 - accuracy: 0.9903 - val_loss: 0.1675 - val_accuracy: 0.9550
# Epoch 9/20
# 203/203 [==============================] - 5s 27ms/step - loss: 0.0184 - accuracy: 0.9935 - val_loss: 0.1924 - val_accuracy: 0.9544
# Epoch 10/20
# 203/203 [==============================] - 5s 27ms/step - loss: 0.0035 - accuracy: 0.9994 - val_loss: 0.2178 - val_accuracy: 0.9661
# Epoch 11/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0167 - accuracy: 0.9934 - val_loss: 0.1771 - val_accuracy: 0.9618
# Epoch 12/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0169 - accuracy: 0.9957 - val_loss: 0.1695 - val_accuracy: 0.9618
# Epoch 13/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.2555 - val_accuracy: 0.9550
# Epoch 14/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0217 - accuracy: 0.9940 - val_loss: 0.2706 - val_accuracy: 0.9513
# Epoch 15/20
# 203/203 [==============================] - 5s 26ms/step - loss: 0.0147 - accuracy: 0.9938 - val_loss: 0.1820 - val_accuracy: 0.9636
# Epoch 16/20
# 203/203 [==============================] - 5s 26ms/step - loss: 8.2495e-04 - accuracy: 1.0000 - val_loss: 0.2045 - val_accuracy: 0.9655
# Epoch 17/20
# 203/203 [==============================] - 5s 26ms/step - loss: 1.4005e-04 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9686
# Epoch 18/20
# 203/203 [==============================] - 5s 26ms/step - loss: 6.3421e-05 - accuracy: 1.0000 - val_loss: 0.2154 - val_accuracy: 0.9686
# Epoch 19/20
# 203/203 [==============================] - 5s 26ms/step - loss: 4.5035e-05 - accuracy: 1.0000 - val_loss: 0.2202 - val_accuracy: 0.9680
# Epoch 20/20
# 203/203 [==============================] - 5s 26ms/step - loss: 3.4826e-05 - accuracy: 1.0000 - val_loss: 0.2244 - val_accuracy: 0.9686
# 114.63963103294373
